# %%
from timeit import default_timer as timer

import matplotlib.pyplot as plt
import numpy as np

import gropt_torch as gropt
# Out:
# Traceback (most recent call last):
#
#   File c:\Users\bughh\.conda\envs\NUM\Lib\site-packages\IPython\core\interactiveshell.py:3672 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[1], line 6
#     import gropt_torch as gropt
#
#   File E:\MGH\gropt-dev\gropt-torch\gropt_torch\__init__.py:5
#     from .core.gropt_params import GroptParams, SolveResult
#
#   File E:\MGH\gropt-dev\gropt-torch\gropt_torch\core\gropt_params.py:179
#     def add_TV(self, tv_lam: float = 0.0, weight_mod: float = 1.0):
#                                                                    ^
# IndentationError: unindent does not match any outer indentation level

# %%
gparams = gropt.GroptParams()
gparams.N = 133
gparams.dt = 10e-6

gparams.add_gmax(.08)
gparams.add_smax(200)
gparams.add_moment(0,0.0)
gparams.add_moment(1,14.0)

start_t = timer()
result = gropt.solve(gparams)
out = result.X
stop_t = timer()

print(f'Converged: {result.converged}  Solve time: {1000*(stop_t-start_t):.1f} ms')

plt.figure(figsize=(6,3))
tt_ms = np.arange(out.size)*gparams.dt*1e3
plt.plot(tt_ms, out)
plt.show()
